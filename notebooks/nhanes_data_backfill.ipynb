# %% [markdown]
# # This notebook add all the data to the same "master" dataset, including documentation of the variables and all the years.
#
# 1. Download documentation for the variables.
# 2. Select the variables needed based on the paper.
# 3. Merge all the files together

# %%
import os
#%load_ext cudf.pandas
import pandas as pd
import numpy as np
from glob import glob
import requests
from bs4 import BeautifulSoup
import io
import pyreadstat

# %%
DATA_PATH = "/Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/"

# %% [markdown]
# # 1. Download NHANES Data

# %% [markdown]
# Downloading the files takess from 15 min to 30 min per year with high speed internet, the good thing is that in can get interrupted at it skips the files already downloaded - just make sure the last file was correctly writen.

# %%
def scrape_nhanes_xpt_files(year, DATA_PAT=DATA_PATH):
    """
    Note PAXMIN.XPT aka "Physical Activity Monitor - Minute	" is the only file missing.
    It's +6 gigas and CDC website its not preciselly fast.
    It takes 6 hours to download usually.
    Polling data without a unique identifer also will be missing ("*POL*.parquet") since
    I have no use for it
    """

    list_types = ["Demographics", "Dietary", "Examination", "Laboratory", "Questionnaire"]

    # Create folder structure for the data based on the year
    os.chdir(DATA_PATH)
    os.makedirs(f"{year}-{year+1}", exist_ok=True)
    os.chdir(f"{year}-{year+1}")

    print(f"NHANES Data from {year}-{year+1} year")
    print("__________________________")
    print("__________________________")

    for type in list_types:
        # Type of data and year
        url = f"https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component={type}&CycleBeginYear={year}"

        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
            continue

        # Create folder structure for the data based on the data type
        os.makedirs(type, exist_ok=True)
        os.chdir(type)
        print("### Data type:", type, "###")
        print("__________________________")

        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all links that end with .XPT (case insensitive)
        xpt_links = soup.find_all('a', href=lambda href: href and href.lower().endswith('.xpt'))

        # Download and process each XPT file
        for link in xpt_links:
            file_url = link['href']
            if not file_url.startswith('http') and not "PAXMIN" in file_url and not "POL" in file_url:
                file_url = f"https://wwwn.cdc.gov{file_url}"
            else:
                continue

            file_name = file_url.split('/')[-1]
            parquet_filename = file_name.replace('.XPT', '.parquet')

            # Download the XPT file if it doesn't exist
            if not os.path.exists(parquet_filename):
                print(f"Downloading {file_name} from CDC website...")
                file_response = requests.get(file_url)
                if file_response.status_code == 200:
                    # Create a temporary file so pyreadstat can read it
                    with tempfile.NamedTemporaryFile(delete=False, suffix='.XPT') as temp_file:
                        temp_file.write(file_response.content)
                        temp_file_path = temp_file.name

                    xpt_data, _ = pyreadstat.read_xport(temp_file_path, encoding='cp1252')
                    xpt_data.to_parquet(parquet_filename, index=False)

                    # Remove the temporary file
                    os.unlink(temp_file_path)
                    print(f"Saved as {parquet_filename}")
                else:
                    print(f"Failed to download {file_name}. Status code: {file_response.status_code}")
            else:
                print(f"{parquet_filename} file already in the destination folder")

        # Moving again to parent directory
        os.chdir('..')
        print("__________________________")

years = [1999,2001,2003,2005,2007,2009,2011,2013]
for year in years:
    scrape_nhanes_xpt_files(year)
# Out:
# NHANES Data from 1999-2000 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DRXIFF.parquet file already in the destination folder
# DRXTOT.parquet file already in the destination folder
# DRXFMT.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DSQFILE1.parquet file already in the destination folder
# DSQFILE2.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# AUX1.parquet file already in the destination folder
# AUXAR.parquet file already in the destination folder
# AUXTYM.parquet file already in the destination folder
# BAX.parquet file already in the destination folder
# BIX.parquet file already in the destination folder
# BPX.parquet file already in the destination folder
# BMX.parquet file already in the destination folder
# CVX.parquet file already in the destination folder
# LEXABPI.parquet file already in the destination folder
# LEXPN.parquet file already in the destination folder
# MSX.parquet file already in the destination folder
# OHXDENT.parquet file already in the destination folder
# OHXPERIO.parquet file already in the destination folder
# OHXREF.parquet file already in the destination folder
# SEQ.parquet file already in the destination folder
# TB.parquet file already in the destination folder
# VIX.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# SSAFB_A.parquet file already in the destination folder
# LAB16.parquet file already in the destination folder
# SSAMH_A.parquet file already in the destination folder
# SSDFS_A.parquet file already in the destination folder
# SSANA_A.parquet file already in the destination folder
# SSANA2_A.parquet file already in the destination folder
# LAB06.parquet file already in the destination folder
# LAB05.parquet file already in the destination folder
# LAB13AM.parquet file already in the destination folder
# LAB13.parquet file already in the destination folder
# LAB25.parquet file already in the destination folder
# LAB11.parquet file already in the destination folder
# LAB17.parquet file already in the destination folder
# SSCYST_A.parquet file already in the destination folder
# SSCMV_A.parquet file already in the destination folder
# SSCMVG_A.parquet file already in the destination folder
# SSUCSH_A.parquet file already in the destination folder
# LAB28POC.parquet file already in the destination folder
# PH.parquet file already in the destination folder
# SSFOL_A.parquet file already in the destination folder
# SSCARD_A.parquet file already in the destination folder
# LAB10.parquet file already in the destination folder
# L02HPA_A.parquet file already in the destination folder
# L02HBS.parquet file already in the destination folder
# LAB02.parquet file already in the destination folder
# LAB09.parquet file already in the destination folder
# SSHSV1_A.parquet file already in the destination folder
# SSTROP_A.parquet file already in the destination folder
# LAB03.parquet file already in the destination folder
# LAB07.parquet file already in the destination folder
# LAB20.parquet file already in the destination folder
# LAB19.parquet file already in the destination folder
# LAB22.parquet file already in the destination folder
# LAB06HM.parquet file already in the destination folder
# SSOL_A.parquet file already in the destination folder
# SSMUMP_A.parquet file already in the destination folder
# SSNORO_A.parquet file already in the destination folder
# SSBNP_A.parquet file already in the destination folder
# SSPFC_A.parquet file already in the destination folder
# LAB26PP.parquet file already in the destination folder
# PHPYPA.parquet file already in the destination folder
# LAB10AM.parquet file already in the destination folder
# UC.parquet file already in the destination folder
# SSCHL_A.parquet file already in the destination folder
# LAB18.parquet file already in the destination folder
# TELO_A.parquet file already in the destination folder
# LAB18T4.parquet file already in the destination folder
# TFA_A.parquet file already in the destination folder
# SSTFR_A.parquet file already in the destination folder
# SSVARI_A.parquet file already in the destination folder
# LAB04.parquet file already in the destination folder
# LAB21.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ.parquet file already in the destination folder
# ALQ.parquet file already in the destination folder
# RXQ_ANA.parquet file already in the destination folder
# AUQ.parquet file already in the destination folder
# BAQ.parquet file already in the destination folder
# BPQ.parquet file already in the destination folder
# CDQ.parquet file already in the destination folder
# CFQ.parquet file already in the destination folder
# HSQ.parquet file already in the destination folder
# DEQ.parquet file already in the destination folder
# DIQ.parquet file already in the destination folder
# DBQ.parquet file already in the destination folder
# DUQ.parquet file already in the destination folder
# ECQ.parquet file already in the destination folder
# FSQ.parquet file already in the destination folder
# HIQ.parquet file already in the destination folder
# HUQ.parquet file already in the destination folder
# HOQ.parquet file already in the destination folder
# IMQ.parquet file already in the destination folder
# KIQ.parquet file already in the destination folder
# MCQ.parquet file already in the destination folder
# CIQMDEP.parquet file already in the destination folder
# CIQGAD.parquet file already in the destination folder
# CIQPANIC.parquet file already in the destination folder
# MPQ.parquet file already in the destination folder
# OCQ.parquet file already in the destination folder
# OHQ.parquet file already in the destination folder
# OSQ.parquet file already in the destination folder
# PUQ.parquet file already in the destination folder
# PAQ.parquet file already in the destination folder
# PAQIAF.parquet file already in the destination folder
# PFQ.parquet file already in the destination folder
# RXQ_RX.parquet file already in the destination folder
# RHQ.parquet file already in the destination folder
# RDQ.parquet file already in the destination folder
# SXQ.parquet file already in the destination folder
# SMQMEC.parquet file already in the destination folder
# SMQ.parquet file already in the destination folder
# SMQFAM.parquet file already in the destination folder
# SSQ.parquet file already in the destination folder
# TBQ.parquet file already in the destination folder
# VIQ.parquet file already in the destination folder
# WHQ.parquet file already in the destination folder
# __________________________
# NHANES Data from 2001-2002 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_B.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DRXIFF_B.parquet file already in the destination folder
# DRXTOT_B.parquet file already in the destination folder
# DRXFMT_B.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DSQ1_B.parquet file already in the destination folder
# DSQ2_B.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# AUX_B.parquet file already in the destination folder
# AUXAR_B.parquet file already in the destination folder
# AUXTYM_B.parquet file already in the destination folder
# BAX_B.parquet file already in the destination folder
# BIX_B.parquet file already in the destination folder
# BPX_B.parquet file already in the destination folder
# BMX_B.parquet file already in the destination folder
# CVX_B.parquet file already in the destination folder
# DXX_2_B.parquet file already in the destination folder
# LEXAB_B.parquet file already in the destination folder
# LEXPN_B.parquet file already in the destination folder
# MSX_B.parquet file already in the destination folder
# OHXDEN_B.parquet file already in the destination folder
# OHXPRL_B.parquet file already in the destination folder
# OHXPRU_B.parquet file already in the destination folder
# OHXREF_B.parquet file already in the destination folder
# VIX_B.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# L16_B.parquet file already in the destination folder
# SSAMH_B.parquet file already in the destination folder
# SSDFS_A.parquet file already in the destination folder
# SSANA_A.parquet file already in the destination folder
# SSANA2_A.parquet file already in the destination folder
# L34_B.parquet file already in the destination folder
# SSBFR_B.parquet file already in the destination folder
# L06_B.parquet file already in the destination folder
# L06_2_B.parquet file already in the destination folder
# SSCA_B.parquet file already in the destination folder
# SSCGA_B.parquet file already in the destination folder
# L05_B.parquet file already in the destination folder
# L13AM_B.parquet file already in the destination folder
# L13_B.parquet file already in the destination folder
# L13_2_B.parquet file already in the destination folder
# L25_B.parquet file already in the destination folder
# L25_2_B.parquet file already in the destination folder
# L11_2_B.parquet file already in the destination folder
# L11_B.parquet file already in the destination folder
# L16_2_B.parquet file already in the destination folder
# SSCYST_B.parquet file already in the destination folder
# SSCMV_B.parquet file already in the destination folder
# SSCMVG_A.parquet file already in the destination folder
# SSUCSH_A.parquet file already in the destination folder
# L28POC_B.parquet file already in the destination folder
# L39_2_B.parquet file already in the destination folder
# L39_B.parquet file already in the destination folder
# PH_B.parquet file already in the destination folder
# SSCARD_A.parquet file already in the destination folder
# L10_B.parquet file already in the destination folder
# L10_2_B.parquet file already in the destination folder
# L02HPA_B.parquet file already in the destination folder
# L02HBS_B.parquet file already in the destination folder
# L02_B.parquet file already in the destination folder
# L09_B.parquet file already in the destination folder
# SSHSV1_B.parquet file already in the destination folder
# SSTROP_A.parquet file already in the destination folder
# L03_B.parquet file already in the destination folder
# SSHE4_B.parquet file already in the destination folder
# L06UIO_B.parquet file already in the destination folder
# L40FE_B.parquet file already in the destination folder
# L20_B.parquet file already in the destination folder
# L19_B.parquet file already in the destination folder
# L19_2_B.parquet file already in the destination folder
# L06HM_B.parquet file already in the destination folder
# L35_B.parquet file already in the destination folder
# SSOL_B.parquet file already in the destination folder
# SSMUMP_B.parquet file already in the destination folder
# SSPCB_B.parquet file already in the destination folder
# SSBNP_A.parquet file already in the destination folder
# SSNO3P_B.parquet file already in the destination folder
# L26PP_B.parquet file already in the destination folder
# SSPST_B.parquet file already in the destination folder
# PHPYPA_B.parquet file already in the destination folder
# L10AM_B.parquet file already in the destination folder
# PFC_POOL.parquet file already in the destination folder
# UC_B.parquet file already in the destination folder
# L11PSA_B.parquet file already in the destination folder
# L11P_2_B.parquet file already in the destination folder
# SSCHL_B.parquet file already in the destination folder
# L40_B.parquet file already in the destination folder
# L40_2_B.parquet file already in the destination folder
# L36_B.parquet file already in the destination folder
# TELO_B.parquet file already in the destination folder
# L40T4_B.parquet file already in the destination folder
# SSNH4THY.parquet file already in the destination folder
# L17_B.parquet file already in the destination folder
# SSTFR_B.parquet file already in the destination folder
# SSVARI_B.parquet file already in the destination folder
# L06VIT_B.parquet file already in the destination folder
# VIT_2_B.parquet file already in the destination folder
# L04VOC_B.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_B.parquet file already in the destination folder
# ALQ_B.parquet file already in the destination folder
# RXQANA_B.parquet file already in the destination folder
# AUQ_B.parquet file already in the destination folder
# BAQ_B.parquet file already in the destination folder
# BPQ_B.parquet file already in the destination folder
# CDQ_B.parquet file already in the destination folder
# CFQ_B.parquet file already in the destination folder
# HSQ_B.parquet file already in the destination folder
# DEQ_B.parquet file already in the destination folder
# DIQ_B.parquet file already in the destination folder
# DBQ_B.parquet file already in the destination folder
# DUQ_B.parquet file already in the destination folder
# ECQ_B.parquet file already in the destination folder
# FSQ_B.parquet file already in the destination folder
# HIQ_B.parquet file already in the destination folder
# HCQ_B.parquet file already in the destination folder
# HUQ_B.parquet file already in the destination folder
# HOQ_B.parquet file already in the destination folder
# IMQ_B.parquet file already in the destination folder
# KIQ_U_B.parquet file already in the destination folder
# MCQ_B.parquet file already in the destination folder
# CIQDEP_B.parquet file already in the destination folder
# CIQGAD_B.parquet file already in the destination folder
# CIQPAN_B.parquet file already in the destination folder
# MPQ_B.parquet file already in the destination folder
# OCQ_B.parquet file already in the destination folder
# OHQ_B.parquet file already in the destination folder
# OSQ_B.parquet file already in the destination folder
# PUQ_B.parquet file already in the destination folder
# PAQ_B.parquet file already in the destination folder
# PAQIAF_B.parquet file already in the destination folder
# PFQ_B.parquet file already in the destination folder
# RXQ_RX_B.parquet file already in the destination folder
# KIQ_P_B.parquet file already in the destination folder
# RHQ_B.parquet file already in the destination folder
# RDQ_B.parquet file already in the destination folder
# SXQ_B.parquet file already in the destination folder
# SMQMEC_B.parquet file already in the destination folder
# SMQ_B.parquet file already in the destination folder
# SMQFAM_B.parquet file already in the destination folder
# SSQ_B.parquet file already in the destination folder
# VIQ_B.parquet file already in the destination folder
# WHQ_B.parquet file already in the destination folder
# __________________________
# NHANES Data from 2003-2004 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_C.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_C.parquet file already in the destination folder
# DR2IFF_C.parquet file already in the destination folder
# DR1TOT_C.parquet file already in the destination folder
# DR2TOT_C.parquet file already in the destination folder
# DRXFCD_C.parquet file already in the destination folder
# DRXMCD_C.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DSQ1_C.parquet file already in the destination folder
# DSQ2_C.parquet file already in the destination folder
# FOODLK_C.parquet file already in the destination folder
# VARLK_C.parquet file already in the destination folder
# FFQDC_C.parquet file already in the destination folder
# FFQRAW_C.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# AUX_C.parquet file already in the destination folder
# AUXAR_C.parquet file already in the destination folder
# AUXTYM_C.parquet file already in the destination folder
# BAX_C.parquet file already in the destination folder
# BIX_C.parquet file already in the destination folder
# BPX_C.parquet file already in the destination folder
# BMX_C.parquet file already in the destination folder
# CVX_C.parquet file already in the destination folder
# DEX_C.parquet file already in the destination folder
# DXXAG_C.parquet file already in the destination folder
# LEXAB_C.parquet file already in the destination folder
# LEXPN_C.parquet file already in the destination folder
# OHXADD_C.parquet file already in the destination folder
# OHXDEN_C.parquet file already in the destination folder
# OHXPRL_C.parquet file already in the destination folder
# OHXPRU_C.parquet file already in the destination folder
# OHXREF_C.parquet file already in the destination folder
# VIX_C.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# L06AGE_C.parquet file already in the destination folder
# L16_C.parquet file already in the destination folder
# SSAMH_C.parquet file already in the destination folder
# L06UAS_C.parquet file already in the destination folder
# SSDFS_A.parquet file already in the destination folder
# SSANA_A.parquet file already in the destination folder
# SSANA2_A.parquet file already in the destination folder
# L34_C.parquet file already in the destination folder
# L28PBE_C.parquet file already in the destination folder
# L06BMT_C.parquet file already in the destination folder
# L05_C.parquet file already in the destination folder
# L13AM_C.parquet file already in the destination folder
# L13_C.parquet file already in the destination folder
# L25_C.parquet file already in the destination folder
# L06COT_C.parquet file already in the destination folder
# SSQFEV_C.parquet file already in the destination folder
# L11_C.parquet file already in the destination folder
# SSCMV_C.parquet file already in the destination folder
# SSCMVG_A.parquet file already in the destination folder
# SSUCSH_A.parquet file already in the destination folder
# L28DFP_C.parquet file already in the destination folder
# L24EPH_C.parquet file already in the destination folder
# SSEBV_C.parquet file already in the destination folder
# L39EPP_C.parquet file already in the destination folder
# PH_C.parquet file already in the destination folder
# SSFA_C.parquet file already in the destination folder
# L06TFR_C.parquet file already in the destination folder
# L06NB_C.parquet file already in the destination folder
# SSCARD_A.parquet file already in the destination folder
# L10_C.parquet file already in the destination folder
# L02HPA_C.parquet file already in the destination folder
# L02HBS_C.parquet file already in the destination folder
# L02_C.parquet file already in the destination folder
# SSHCVR_C.parquet file already in the destination folder
# L09_C.parquet file already in the destination folder
# SSTROP_A.parquet file already in the destination folder
# L03_C.parquet file already in the destination folder
# L52SER_C.parquet file already in the destination folder
# L37SWA_C.parquet file already in the destination folder
# L37SWR_C.parquet file already in the destination folder
# L06UIO_C.parquet file already in the destination folder
# L40FE_C.parquet file already in the destination folder
# L20_C.parquet file already in the destination folder
# L19_C.parquet file already in the destination folder
# SSMEL_C.parquet file already in the destination folder
# L06UHG_C.parquet file already in the destination folder
# L06HM_C.parquet file already in the destination folder
# L35_C.parquet file already in the destination folder
# L06MH_C.parquet file already in the destination folder
# SSOL_C.parquet file already in the destination folder
# SSMUMP_C.parquet file already in the destination folder
# L28NPB_C.parquet file already in the destination folder
# SSNORO_C.parquet file already in the destination folder
# SSBNP_A.parquet file already in the destination folder
# L26OPD_C.parquet file already in the destination folder
# L04PER_C.parquet file already in the destination folder
# L26UPP_C.parquet file already in the destination folder
# L24PP_C.parquet file already in the destination folder
# L28OCP_C.parquet file already in the destination folder
# L24PH_C.parquet file already in the destination folder
# L06PHY_C.parquet file already in the destination folder
# L10AM_C.parquet file already in the destination folder
# L31PAH_C.parquet file already in the destination folder
# L24PFC_C.parquet file already in the destination folder
# UC_C.parquet file already in the destination folder
# L11PSA_C.parquet file already in the destination folder
# SSCHL_C.parquet file already in the destination folder
# L40_C.parquet file already in the destination folder
# L36_C.parquet file already in the destination folder
# L17_C.parquet file already in the destination folder
# SSVARI_C.parquet file already in the destination folder
# L45VIT_C.parquet file already in the destination folder
# L43_C.parquet file already in the destination folder
# L06VIT_C.parquet file already in the destination folder
# L04VOC_C.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_C.parquet file already in the destination folder
# ALQ_C.parquet file already in the destination folder
# RXQANA_C.parquet file already in the destination folder
# AUQ_C.parquet file already in the destination folder
# BAQ_C.parquet file already in the destination folder
# BPQ_C.parquet file already in the destination folder
# CDQ_C.parquet file already in the destination folder
# HSQ_C.parquet file already in the destination folder
# DEQ_C.parquet file already in the destination folder
# DIQ_C.parquet file already in the destination folder
# DBQ_C.parquet file already in the destination folder
# DUQ_C.parquet file already in the destination folder
# ECQ_C.parquet file already in the destination folder
# FSQ_C.parquet file already in the destination folder
# HIQ_C.parquet file already in the destination folder
# HCQ_C.parquet file already in the destination folder
# HUQ_C.parquet file already in the destination folder
# HOQ_C.parquet file already in the destination folder
# IMQ_C.parquet file already in the destination folder
# KIQ_U_C.parquet file already in the destination folder
# MCQ_C.parquet file already in the destination folder
# CIQDEP_C.parquet file already in the destination folder
# CIQGAD_C.parquet file already in the destination folder
# CIQPAN_C.parquet file already in the destination folder
# MPQ_C.parquet file already in the destination folder
# OCQ_C.parquet file already in the destination folder
# OHQ_C.parquet file already in the destination folder
# OSQ_C.parquet file already in the destination folder
# PUQ_C.parquet file already in the destination folder
# PAQ_C.parquet file already in the destination folder
# PAQIAF_C.parquet file already in the destination folder
# PFQ_C.parquet file already in the destination folder
# RXQ_RX_C.parquet file already in the destination folder
# KIQ_P_C.parquet file already in the destination folder
# PSQ_C.parquet file already in the destination folder
# RHQ_C.parquet file already in the destination folder
# RDQ_C.parquet file already in the destination folder
# SXQ_C.parquet file already in the destination folder
# SMQMEC_C.parquet file already in the destination folder
# SMQ_C.parquet file already in the destination folder
# SMQFAM_C.parquet file already in the destination folder
# SSQ_C.parquet file already in the destination folder
# VIQ_C.parquet file already in the destination folder
# WHQ_C.parquet file already in the destination folder
# __________________________
# NHANES Data from 2005-2006 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_D.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_D.parquet file already in the destination folder
# DR2IFF_D.parquet file already in the destination folder
# DR1TOT_D.parquet file already in the destination folder
# DR2TOT_D.parquet file already in the destination folder
# DRXFCD_D.parquet file already in the destination folder
# DRXMCD_D.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DSQ1_D.parquet file already in the destination folder
# DSQ2_D.parquet file already in the destination folder
# FOODLK_D.xpt file already in the destination folder
# VARLK_D.xpt file already in the destination folder
# FFQDC_D.parquet file already in the destination folder
# FFQRAW_D.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# AUX_D.parquet file already in the destination folder
# AUXAR_D.parquet file already in the destination folder
# AUXTYM_D.parquet file already in the destination folder
# BPX_D.parquet file already in the destination folder
# BMX_D.parquet file already in the destination folder
# DXXAG_D.parquet file already in the destination folder
# DXXFEM_D.parquet file already in the destination folder
# DXXSPN_D.parquet file already in the destination folder
# OPXFDT_D.parquet file already in the destination folder
# OPXRET_D.parquet file already in the destination folder
# OHX_D.parquet file already in the destination folder
# VIX_D.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# AMDGYD_D.parquet file already in the destination folder
# ALB_CR_D.parquet file already in the destination folder
# AL_IGE_D.parquet file already in the destination folder
# ALDUST_D.parquet file already in the destination folder
# UAS_D.parquet file already in the destination folder
# PBCD_D.parquet file already in the destination folder
# CHLMDA_D.parquet file already in the destination folder
# HDL_D.parquet file already in the destination folder
# TRIGLY_D.parquet file already in the destination folder
# TCHOL_D.parquet file already in the destination folder
# CBC_D.parquet file already in the destination folder
# COT_D.parquet file already in the destination folder
# CRP_D.parquet file already in the destination folder
# EPH_D.parquet file already in the destination folder
# SSEBV_D.parquet file already in the destination folder
# EPP_D.parquet file already in the destination folder
# FASTQX_D.parquet file already in the destination folder
# FERTIN_D.parquet file already in the destination folder
# FOLATE_D.parquet file already in the destination folder
# GHB_D.parquet file already in the destination folder
# HEPA_D.parquet file already in the destination folder
# HEPB_S_D.parquet file already in the destination folder
# HEPBD_D.parquet file already in the destination folder
# HEPC_D.parquet file already in the destination folder
# HSV_D.parquet file already in the destination folder
# HIV_D.parquet file already in the destination folder
# HCY_D.parquet file already in the destination folder
# HPVSER_D.parquet file already in the destination folder
# HPVSRM_D.parquet file already in the destination folder
# HPVSWR_D.parquet file already in the destination folder
# UIO_D.parquet file already in the destination folder
# FETIB_D.parquet file already in the destination folder
# IHG_D.parquet file already in the destination folder
# UHG_D.parquet file already in the destination folder
# UHM_D.parquet file already in the destination folder
# OGTT_D.parquet file already in the destination folder
# OPD_D.parquet file already in the destination folder
# PTH_D.parquet file already in the destination folder
# WPIN_D.parquet file already in the destination folder
# PERNT_D.parquet file already in the destination folder
# CARB_D.parquet file already in the destination folder
# UPP_D.parquet file already in the destination folder
# PP_D.parquet file already in the destination folder
# PHTHTE_D.parquet file already in the destination folder
# PHYTO_D.parquet file already in the destination folder
# GLU_D.parquet file already in the destination folder
# PAH_D.parquet file already in the destination folder
# PFC_D.parquet file already in the destination folder
# POOLTF_D.parquet file already in the destination folder
# UCPREG_D.parquet file already in the destination folder
# PSA_D.parquet file already in the destination folder
# SSSAL_D.parquet file already in the destination folder
# BIOPRO_D.parquet file already in the destination folder
# TFR_D.parquet file already in the destination folder
# VITAEC_D.parquet file already in the destination folder
# B12_D.parquet file already in the destination folder
# VIT_B6_D.parquet file already in the destination folder
# VIC_D.parquet file already in the destination folder
# SSUVOC_D.parquet file already in the destination folder
# VOCWB_D.parquet file already in the destination folder
# VOC_D.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_D.parquet file already in the destination folder
# ALQ_D.parquet file already in the destination folder
# AGQ_D.parquet file already in the destination folder
# AUQ_D.parquet file already in the destination folder
# BPQ_D.parquet file already in the destination folder
# BHQ_D.parquet file already in the destination folder
# CDQ_D.parquet file already in the destination folder
# HSQ_D.parquet file already in the destination folder
# DEQ_D.parquet file already in the destination folder
# DIQ_D.parquet file already in the destination folder
# DBQ_D.parquet file already in the destination folder
# DUQ_D.parquet file already in the destination folder
# ECQ_D.parquet file already in the destination folder
# FSQ_D.parquet file already in the destination folder
# HIQ_D.parquet file already in the destination folder
# HCQ_D.parquet file already in the destination folder
# HUQ_D.parquet file already in the destination folder
# HOQ_D.parquet file already in the destination folder
# IMQ_D.parquet file already in the destination folder
# KIQ_U_D.parquet file already in the destination folder
# MCQ_D.parquet file already in the destination folder
# DPQ_D.parquet file already in the destination folder
# OCQ_D.parquet file already in the destination folder
# OHQ_D.parquet file already in the destination folder
# OSQ_D.parquet file already in the destination folder
# PUQMEC_D.parquet file already in the destination folder
# PAQ_D.parquet file already in the destination folder
# PAQIAF_D.parquet file already in the destination folder
# PFQ_D.parquet file already in the destination folder
# RXQ_RX_D.parquet file already in the destination folder
# KIQ_P_D.parquet file already in the destination folder
# PSQ_D.parquet file already in the destination folder
# RHQ_D.parquet file already in the destination folder
# RDQ_D.parquet file already in the destination folder
# SXQ_D.parquet file already in the destination folder
# SLQ_D.parquet file already in the destination folder
# SMQ_D.parquet file already in the destination folder
# SMQFAM_D.parquet file already in the destination folder
# SMQRTU_D.parquet file already in the destination folder
# SSQ_D.parquet file already in the destination folder
# VIQ_D.parquet file already in the destination folder
# WHQ_D.parquet file already in the destination folder
# WHQMEC_D.parquet file already in the destination folder
# __________________________
# NHANES Data from 2007-2008 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_E.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_E.parquet file already in the destination folder
# DR2IFF_E.parquet file already in the destination folder
# DR1TOT_E.parquet file already in the destination folder
# DR2TOT_E.parquet file already in the destination folder
# DRXFCD_E.parquet file already in the destination folder
# DRXMCD_E.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DS1IDS_E.parquet file already in the destination folder
# DS2IDS_E.parquet file already in the destination folder
# DS1TOT_E.parquet file already in the destination folder
# DS2TOT_E.parquet file already in the destination folder
# DSQIDS_E.parquet file already in the destination folder
# DSQTOT_E.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# AUX_E.parquet file already in the destination folder
# AUXAR_E.parquet file already in the destination folder
# AUXTYM_E.parquet file already in the destination folder
# BPX_E.parquet file already in the destination folder
# BMX_E.parquet file already in the destination folder
# DXXFEM_E.parquet file already in the destination folder
# DXXSPN_E.parquet file already in the destination folder
# ENX_E.parquet file already in the destination folder
# OPXFDT_E.parquet file already in the destination folder
# OPXRET_E.parquet file already in the destination folder
# OHX_E.parquet file already in the destination folder
# SPX_E.parquet file already in the destination folder
# VIX_E.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# ALB_CR_E.parquet file already in the destination folder
# APOB_E.parquet file already in the destination folder
# UAS_E.parquet file already in the destination folder
# UAM_E.parquet file already in the destination folder
# PBCD_E.parquet file already in the destination folder
# CHLMDA_E.parquet file already in the destination folder
# HDL_E.parquet file already in the destination folder
# TRIGLY_E.parquet file already in the destination folder
# TCHOL_E.parquet file already in the destination folder
# CBC_E.parquet file already in the destination folder
# COTNAL_E.parquet file already in the destination folder
# CRP_E.parquet file already in the destination folder
# DEET_E.parquet file already in the destination folder
# EPH_E.parquet file already in the destination folder
# SSEBV_E.parquet file already in the destination folder
# FASTQX_E.parquet file already in the destination folder
# FERTIN_E.parquet file already in the destination folder
# FOLATE_E.parquet file already in the destination folder
# FOLFMS_E.parquet file already in the destination folder
# GHB_E.parquet file already in the destination folder
# HEPA_E.parquet file already in the destination folder
# HEPB_S_E.parquet file already in the destination folder
# HEPBD_E.parquet file already in the destination folder
# SSHCV_E.parquet file already in the destination folder
# HEPC_E.parquet file already in the destination folder
# HSV_E.parquet file already in the destination folder
# HIV_E.parquet file already in the destination folder
# HPVSER_E.parquet file already in the destination folder
# HPVSWR_E.parquet file already in the destination folder
# UIO_E.parquet file already in the destination folder
# SSKL_E.parquet file already in the destination folder
# IHG_E.parquet file already in the destination folder
# UHG_E.parquet file already in the destination folder
# UHM_E.parquet file already in the destination folder
# OGTT_E.parquet file already in the destination folder
# OPD_E.parquet file already in the destination folder
# PERNT_E.parquet file already in the destination folder
# CARB_E.parquet file already in the destination folder
# UPP_E.parquet file already in the destination folder
# PP_E.parquet file already in the destination folder
# PHTHTE_E.parquet file already in the destination folder
# PHYTO_E.parquet file already in the destination folder
# GLU_E.parquet file already in the destination folder
# PAH_E.parquet file already in the destination folder
# PFC_E.parquet file already in the destination folder
# POOLTF_E.parquet file already in the destination folder
# UCPREG_E.parquet file already in the destination folder
# PSA_E.parquet file already in the destination folder
# UPHOPM_E.parquet file already in the destination folder
# BIOPRO_E.parquet file already in the destination folder
# THYROD_E.parquet file already in the destination folder
# TFR_E.parquet file already in the destination folder
# SSUSG_E.parquet file already in the destination folder
# VIT_B6_E.parquet file already in the destination folder
# VOCWB_E.parquet file already in the destination folder
# VOCMWB_E.parquet file already in the destination folder
# VOC_E.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_E.parquet file already in the destination folder
# AQQ_E.parquet file already in the destination folder
# ALQ_E.parquet file already in the destination folder
# AUQ_E.parquet file already in the destination folder
# BPQ_E.parquet file already in the destination folder
# BHQ_E.parquet file already in the destination folder
# CDQ_E.parquet file already in the destination folder
# CBQ_E.parquet file already in the destination folder
# CBQPFA_E.parquet file already in the destination folder
# CBQPFC_E.parquet file already in the destination folder
# HSQ_E.parquet file already in the destination folder
# DIQ_E.parquet file already in the destination folder
# DBQ_E.parquet file already in the destination folder
# DUQ_E.parquet file already in the destination folder
# ECQ_E.parquet file already in the destination folder
# FSQ_E.parquet file already in the destination folder
# HIQ_E.parquet file already in the destination folder
# HCQ_E.parquet file already in the destination folder
# HUQ_E.parquet file already in the destination folder
# HOQ_E.parquet file already in the destination folder
# IMQ_E.parquet file already in the destination folder
# INQ_E.parquet file already in the destination folder
# KIQ_U_E.parquet file already in the destination folder
# MCQ_E.parquet file already in the destination folder
# DPQ_E.parquet file already in the destination folder
# OCQ_E.parquet file already in the destination folder
# OHQ_E.parquet file already in the destination folder
# OSQ_E.parquet file already in the destination folder
# PUQMEC_E.parquet file already in the destination folder
# PAQ_E.parquet file already in the destination folder
# PFQ_E.parquet file already in the destination folder
# RXQ_RX_E.parquet file already in the destination folder
# KIQ_P_E.parquet file already in the destination folder
# RHQ_E.parquet file already in the destination folder
# RDQ_E.parquet file already in the destination folder
# SXQ_E.parquet file already in the destination folder
# SLQ_E.parquet file already in the destination folder
# SMQ_E.parquet file already in the destination folder
# SMQFAM_E.parquet file already in the destination folder
# SMQRTU_E.parquet file already in the destination folder
# SSQ_E.parquet file already in the destination folder
# VIQ_E.parquet file already in the destination folder
# WHQ_E.parquet file already in the destination folder
# WHQMEC_E.parquet file already in the destination folder
# __________________________
# NHANES Data from 2009-2010 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_F.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_F.parquet file already in the destination folder
# DR2IFF_F.parquet file already in the destination folder
# DR1TOT_F.parquet file already in the destination folder
# DR2TOT_F.parquet file already in the destination folder
# DRXFCD_F.parquet file already in the destination folder
# DRXMCD_F.parquet file already in the destination folder
# DTQ_F.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DS1IDS_F.parquet file already in the destination folder
# DS2IDS_F.parquet file already in the destination folder
# DS1TOT_F.parquet file already in the destination folder
# DS2TOT_F.parquet file already in the destination folder
# DSQIDS_F.parquet file already in the destination folder
# DSQTOT_F.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# ARX_F.parquet file already in the destination folder
# AUX_F.parquet file already in the destination folder
# AUXAR_F.parquet file already in the destination folder
# AUXTYM_F.parquet file already in the destination folder
# BPX_F.parquet file already in the destination folder
# BMX_F.parquet file already in the destination folder
# DXXFEM_F.parquet file already in the destination folder
# DXXSPN_F.parquet file already in the destination folder
# ENX_F.parquet file already in the destination folder
# FLXCLN_F.parquet file already in the destination folder
# OHXDEN_F.parquet file already in the destination folder
# OHXPER_F.parquet file already in the destination folder
# OHXREF_F.parquet file already in the destination folder
# SPX_F.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# ALB_CR_F.parquet file already in the destination folder
# APOB_F.parquet file already in the destination folder
# UAS_F.parquet file already in the destination folder
# PBCD_F.parquet file already in the destination folder
# CAFE_F.parquet file already in the destination folder
# CHLMDA_F.parquet file already in the destination folder
# HDL_F.parquet file already in the destination folder
# TRIGLY_F.parquet file already in the destination folder
# TCHOL_F.parquet file already in the destination folder
# CBC_F.parquet file already in the destination folder
# COTNAL_F.parquet file already in the destination folder
# CRP_F.parquet file already in the destination folder
# DEET_F.parquet file already in the destination folder
# EPH_F.parquet file already in the destination folder
# SSEBV_F.parquet file already in the destination folder
# FASTQX_F.parquet file already in the destination folder
# FERTIN_F.parquet file already in the destination folder
# FOLATE_F.parquet file already in the destination folder
# GHB_F.parquet file already in the destination folder
# HEPA_F.parquet file already in the destination folder
# HEPB_S_F.parquet file already in the destination folder
# HEPBD_F.parquet file already in the destination folder
# SSHCV_E.parquet file already in the destination folder
# HEPC_F.parquet file already in the destination folder
# HEPE_F.parquet file already in the destination folder
# HSV_F.parquet file already in the destination folder
# HIV_F.parquet file already in the destination folder
# HPVSER_F.parquet file already in the destination folder
# ORHPV_F.parquet file already in the destination folder
# HPVSWR_F.parquet file already in the destination folder
# SSHPV_F.parquet file already in the destination folder
# UIO_F.parquet file already in the destination folder
# SSKL_F.parquet file already in the destination folder
# MMRV_F.parquet file already in the destination folder
# IHG_F.parquet file already in the destination folder
# UHG_F.parquet file already in the destination folder
# UHM_F.parquet file already in the destination folder
# OGTT_F.parquet file already in the destination folder
# UCOSMO_F.parquet file already in the destination folder
# PERNT_F.parquet file already in the destination folder
# PP_F.parquet file already in the destination folder
# PHTHTE_F.parquet file already in the destination folder
# PHYTO_F.parquet file already in the destination folder
# GLU_F.parquet file already in the destination folder
# PAH_F.parquet file already in the destination folder
# PFC_F.parquet file already in the destination folder
# POOLTF_F.parquet file already in the destination folder
# UCPREG_F.parquet file already in the destination folder
# PSA_F.parquet file already in the destination folder
# UPHOPM_F.parquet file already in the destination folder
# BIOPRO_F.parquet file already in the destination folder
# THYROD_F.parquet file already in the destination folder
# TGEMA_F.parquet file already in the destination folder
# SSTOXO_F.parquet file already in the destination folder
# TFA_F.parquet file already in the destination folder
# TFR_F.parquet file already in the destination folder
# UCFLOW_F.parquet file already in the destination folder
# VIT_B6_F.parquet file already in the destination folder
# VOCWB_F.parquet file already in the destination folder
# VOCMWB_F.parquet file already in the destination folder
# VOC_F.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_F.parquet file already in the destination folder
# AQQ_F.parquet file already in the destination folder
# ALQ_F.parquet file already in the destination folder
# ALQY_F.parquet file already in the destination folder
# ARQ_F.parquet file already in the destination folder
# AUQ_F.parquet file already in the destination folder
# BPQ_F.parquet file already in the destination folder
# BHQ_F.parquet file already in the destination folder
# CDQ_F.parquet file already in the destination folder
# CBQ_F.parquet file already in the destination folder
# CBQPFA_F.parquet file already in the destination folder
# CBQPFC_F.parquet file already in the destination folder
# HSQ_F.parquet file already in the destination folder
# DEQ_F.parquet file already in the destination folder
# DIQ_F.parquet file already in the destination folder
# DBQ_F.parquet file already in the destination folder
# DUQ_F.parquet file already in the destination folder
# ECQ_F.parquet file already in the destination folder
# FSQ_F.parquet file already in the destination folder
# HIQ_F.parquet file already in the destination folder
# HCQ_F.parquet file already in the destination folder
# HUQ_F.parquet file already in the destination folder
# HOQ_F.parquet file already in the destination folder
# IMQ_F.parquet file already in the destination folder
# INQ_F.parquet file already in the destination folder
# KIQ_U_F.parquet file already in the destination folder
# MCQ_F.parquet file already in the destination folder
# DPQ_F.parquet file already in the destination folder
# OCQ_F.parquet file already in the destination folder
# OHQ_F.parquet file already in the destination folder
# OSQ_F.parquet file already in the destination folder
# PUQMEC_F.parquet file already in the destination folder
# PAQ_F.parquet file already in the destination folder
# PFQ_F.parquet file already in the destination folder
# RXQ_RX_F.parquet file already in the destination folder
# RHQ_F.parquet file already in the destination folder
# RDQ_F.parquet file already in the destination folder
# SXQ_F.parquet file already in the destination folder
# SLQ_F.parquet file already in the destination folder
# SMQ_F.parquet file already in the destination folder
# SMQFAM_F.parquet file already in the destination folder
# SMQRTU_F.parquet file already in the destination folder
# VTQ_F.parquet file already in the destination folder
# WHQ_F.parquet file already in the destination folder
# WHQMEC_F.parquet file already in the destination folder
# __________________________
# NHANES Data from 2011-2012 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_G.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_G.parquet file already in the destination folder
# DR2IFF_G.parquet file already in the destination folder
# DR1TOT_G.parquet file already in the destination folder
# DR2TOT_G.parquet file already in the destination folder
# DRXFCD_G.parquet file already in the destination folder
# DRXMCD_G.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DS1IDS_G.parquet file already in the destination folder
# ...
# HDL_G.parquet file already in the destination folder
# TRIGLY_G.parquet file already in the destination folder
# TCHOL_G.parquet file already in the destination folder
# CBC_G.parquet file already in the destination folder
# CUSEZN_G.parquet file already in the destination folder
# COTNAL_G.parquet file already in the destination folder
# CMV_G.parquet file already in the destination folder
# DEET_G.parquet file already in the destination folder
# EPH_G.parquet file already in the destination folder
# FASTQX_G.parquet file already in the destination folder
# FAS_G.parquet file already in the destination folder
# SSFR_G.parquet file already in the destination folder
# FOLATE_G.parquet file already in the destination folder
# FOLFMS_G.parquet file already in the destination folder
# GHB_G.parquet file already in the destination folder
# HEPA_G.parquet file already in the destination folder
# HEPB_S_G.parquet file already in the destination folder
# HEPBD_G.parquet file already in the destination folder
# SSHCV_E.parquet file already in the destination folder
# HEPC_G.parquet file already in the destination folder
# HEPE_G.parquet file already in the destination folder
# HSV_G.parquet file already in the destination folder
# HIV_G.parquet file already in the destination folder
# ORHPV_G.parquet file already in the destination folder
# HPVSWR_G.parquet file already in the destination folder
# UIO_G.parquet file already in the destination folder
# SSKL_G.parquet file already in the destination folder
# UHG_G.parquet file already in the destination folder
# IHGEM_G.parquet file already in the destination folder
# UHM_G.parquet file already in the destination folder
# UHMS_G.parquet file already in the destination folder
# MMA_G.parquet file already in the destination folder
# OGTT_G.parquet file already in the destination folder
# OPD_G.parquet file already in the destination folder
# UCOSMO_G.parquet file already in the destination folder
# PERNT_G.parquet file already in the destination folder
# PERNTS_G.parquet file already in the destination folder
# PP_G.parquet file already in the destination folder
# PHTHTE_G.parquet file already in the destination folder
# GLU_G.parquet file already in the destination folder
# PAH_G.parquet file already in the destination folder
# PAHS_G.parquet file already in the destination folder
# PFC_G.parquet file already in the destination folder
# POOLTF_G.parquet file already in the destination folder
# UCPREG_G.parquet file already in the destination folder
# UPHOPM_G.parquet file already in the destination folder
# BIOPRO_G.parquet file already in the destination folder
# THYROD_G.parquet file already in the destination folder
# TGEMA_G.parquet file already in the destination folder
# TST_G.parquet file already in the destination folder
# SSTOXO_G.parquet file already in the destination folder
# TB_G.parquet file already in the destination folder
# UCFLOW_G.parquet file already in the destination folder
# VITB12_G.parquet file already in the destination folder
# VID_G.parquet file already in the destination folder
# UVOC_G.parquet file already in the destination folder
# UVOCS_G.parquet file already in the destination folder
# VOCWB_G.parquet file already in the destination folder
# VOCMWB_G.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_G.parquet file already in the destination folder
# ALQ_G.parquet file already in the destination folder
# AUQ_G.parquet file already in the destination folder
# BPQ_G.parquet file already in the destination folder
# CDQ_G.parquet file already in the destination folder
# CFQ_G.parquet file already in the destination folder
# CBQ_G.parquet file already in the destination folder
# CKQ_G.parquet file already in the destination folder
# HSQ_G.parquet file already in the destination folder
# DEQ_G.parquet file already in the destination folder
# DIQ_G.parquet file already in the destination folder
# DBQ_G.parquet file already in the destination folder
# DUQ_G.parquet file already in the destination folder
# ECQ_G.parquet file already in the destination folder
# FSQ_G.parquet file already in the destination folder
# HIQ_G.parquet file already in the destination folder
# HCQ_G.parquet file already in the destination folder
# HUQ_G.parquet file already in the destination folder
# HOQ_G.parquet file already in the destination folder
# IMQ_G.parquet file already in the destination folder
# INQ_G.parquet file already in the destination folder
# KIQ_U_G.parquet file already in the destination folder
# MCQ_G.parquet file already in the destination folder
# DPQ_G.parquet file already in the destination folder
# OCQ_G.parquet file already in the destination folder
# OHQ_G.parquet file already in the destination folder
# PUQMEC_G.parquet file already in the destination folder
# PAQ_G.parquet file already in the destination folder
# PFQ_G.parquet file already in the destination folder
# RXQ_RX_G.parquet file already in the destination folder
# RXQASA_G.parquet file already in the destination folder
# RHQ_G.parquet file already in the destination folder
# RDQ_G.parquet file already in the destination folder
# SXQ_G.parquet file already in the destination folder
# SLQ_G.parquet file already in the destination folder
# SMQ_G.parquet file already in the destination folder
# SMQFAM_G.parquet file already in the destination folder
# SMQRTU_G.parquet file already in the destination folder
# CSQ_G.parquet file already in the destination folder
# TBQ_G.parquet file already in the destination folder
# VTQ_G.parquet file already in the destination folder
# WHQ_G.parquet file already in the destination folder
# WHQMEC_G.parquet file already in the destination folder
# __________________________
# NHANES Data from 2013-2014 year
# __________________________
# __________________________
# ### Data type: Demographics ###
# __________________________
# DEMO_H.parquet file already in the destination folder
# __________________________
# ### Data type: Dietary ###
# __________________________
# DR1IFF_H.parquet file already in the destination folder
# DR2IFF_H.parquet file already in the destination folder
# DR1TOT_H.parquet file already in the destination folder
# DR2TOT_H.parquet file already in the destination folder
# DRXFCD_H.parquet file already in the destination folder
# DSBI.parquet file already in the destination folder
# DSII.parquet file already in the destination folder
# DSPI.parquet file already in the destination folder
# DS1IDS_H.parquet file already in the destination folder
# DS2IDS_H.parquet file already in the destination folder
# DS1TOT_H.parquet file already in the destination folder
# DS2TOT_H.parquet file already in the destination folder
# DSQIDS_H.parquet file already in the destination folder
# DSQTOT_H.parquet file already in the destination folder
# __________________________
# ### Data type: Examination ###
# __________________________
# BPX_H.parquet file already in the destination folder
# BMX_H.parquet file already in the destination folder
# DXXAAC_H.parquet file already in the destination folder
# DXXAG_H.parquet file already in the destination folder
# DXXFEM_H.parquet file already in the destination folder
# DXXFRX_H.parquet file already in the destination folder
# DXXL1_H.parquet file already in the destination folder
# DXXL2_H.parquet file already in the destination folder
# DXXL3_H.parquet file already in the destination folder
# DXXL4_H.parquet file already in the destination folder
# DXXSPN_H.parquet file already in the destination folder
# DXXT10_H.parquet file already in the destination folder
# DXXT11_H.parquet file already in the destination folder
# DXXT12_H.parquet file already in the destination folder
# DXXT4_H.parquet file already in the destination folder
# DXXT5_H.parquet file already in the destination folder
# DXXT6_H.parquet file already in the destination folder
# DXXT7_H.parquet file already in the destination folder
# DXXT8_H.parquet file already in the destination folder
# DXXT9_H.parquet file already in the destination folder
# DXXVFA_H.parquet file already in the destination folder
# DXX_H.parquet file already in the destination folder
# FLXCLN_H.parquet file already in the destination folder
# MGX_H.parquet file already in the destination folder
# OHXDEN_H.parquet file already in the destination folder
# OHXPER_H.parquet file already in the destination folder
# OHXREF_H.parquet file already in the destination folder
# PAXDAY_H.parquet file already in the destination folder
# PAXHD_H.parquet file already in the destination folder
# PAXHR_H.parquet file already in the destination folder
# CSX_H.parquet file already in the destination folder
# __________________________
# ### Data type: Laboratory ###
# __________________________
# AMDGYD_H.parquet file already in the destination folder
# AMDGDS_H.parquet file already in the destination folder
# ALB_CR_H.parquet file already in the destination folder
# ALD_H.parquet file already in the destination folder
# ALDS_H.parquet file already in the destination folder
# SSTOCA_H.parquet file already in the destination folder
# APOB_H.parquet file already in the destination folder
# AA_H.parquet file already in the destination folder
# AAS_H.parquet file already in the destination folder
# UTAS_H.parquet file already in the destination folder
# UTASS_H.parquet file already in the destination folder
# UAS_H.parquet file already in the destination folder
# UASS_H.parquet file already in the destination folder
# CAFE_H.parquet file already in the destination folder
# CHLMDA_H.parquet file already in the destination folder
# SSCT_H.parquet file already in the destination folder
# HDL_H.parquet file already in the destination folder
# TRIGLY_H.parquet file already in the destination folder
# TCHOL_H.parquet file already in the destination folder
# CBC_H.parquet file already in the destination folder
# CUSEZN_H.parquet file already in the destination folder
# COT_H.parquet file already in the destination folder
# UCOT_H.parquet file already in the destination folder
# UCOTS_H.parquet file already in the destination folder
# DEET_H.parquet file already in the destination folder
# ETHOX_H.parquet file already in the destination folder
# ETHOXS_H.parquet file already in the destination folder
# FASTQX_H.parquet file already in the destination folder
# FAS_H.parquet file already in the destination folder
# SSFLRT_H.parquet file already in the destination folder
# FLDEP_H.parquet file already in the destination folder
# FLDEW_H.parquet file already in the destination folder
# FOLATE_H.parquet file already in the destination folder
# FOLFMS_H.parquet file already in the destination folder
# FORMAL_H.parquet file already in the destination folder
# FORMAS_H.parquet file already in the destination folder
# GHB_H.parquet file already in the destination folder
# SSGLYP_H.parquet file already in the destination folder
# HEPA_H.parquet file already in the destination folder
# HEPBD_H.parquet file already in the destination folder
# HEPB_S_H.parquet file already in the destination folder
# SSHEPC_H.parquet file already in the destination folder
# HEPC_H.parquet file already in the destination folder
# HEPE_H.parquet file already in the destination folder
# HSV_H.parquet file already in the destination folder
# HCAA_H.parquet file already in the destination folder
# HCAAS_H.parquet file already in the destination folder
# HIV_H.parquet file already in the destination folder
# ORHPV_H.parquet file already in the destination folder
# HPVSWR_H.parquet file already in the destination folder
# HPVP_H.parquet file already in the destination folder
# INS_H.parquet file already in the destination folder
# UIO_H.parquet file already in the destination folder
# SSKL_H.parquet file already in the destination folder
# PBCD_H.parquet file already in the destination folder
# UHG_H.parquet file already in the destination folder
# IHGEM_H.parquet file already in the destination folder
# UM_H.parquet file already in the destination folder
# UMS_H.parquet file already in the destination folder
# MMA_H.parquet file already in the destination folder
# OGTT_H.parquet file already in the destination folder
# PERNT_H.parquet file already in the destination folder
# PERNTS_H.parquet file already in the destination folder
# SSPFSU_H.parquet file already in the destination folder
# SSPFAS_H.parquet file already in the destination folder
# PFAS_H.parquet file already in the destination folder
# SSPFAC_H.parquet file already in the destination folder
# EPHPP_H.parquet file already in the destination folder
# PHTHTE_H.parquet file already in the destination folder
# SSPHTE_H.parquet file already in the destination folder
# GLU_H.parquet file already in the destination folder
# PAH_H.parquet file already in the destination folder
# POOLTF_H.parquet file already in the destination folder
# UCPREG_H.parquet file already in the destination folder
# UPHOPM_H.parquet file already in the destination folder
# SSSNFL_H.parquet file already in the destination folder
# TST_H.parquet file already in the destination folder
# BIOPRO_H.parquet file already in the destination folder
# SSTERP_H.parquet file already in the destination folder
# TGEMA_H.parquet file already in the destination folder
# TSNA_H.parquet file already in the destination folder
# SSTOXO_H.parquet file already in the destination folder
# TRICH_H.parquet file already in the destination folder
# UCFLOW_H.parquet file already in the destination folder
# VITB12_H.parquet file already in the destination folder
# VID_H.parquet file already in the destination folder
# VNA_H.parquet file already in the destination folder
# VNAS_H.parquet file already in the destination folder
# UVOC_H.parquet file already in the destination folder
# UVOCS_H.parquet file already in the destination folder
# VOCWBS_H.parquet file already in the destination folder
# VOCWB_H.parquet file already in the destination folder
# __________________________
# ### Data type: Questionnaire ###
# __________________________
# ACQ_H.parquet file already in the destination folder
# ALQ_H.parquet file already in the destination folder
# BPQ_H.parquet file already in the destination folder
# CDQ_H.parquet file already in the destination folder
# CFQ_H.parquet file already in the destination folder
# CBQ_H.parquet file already in the destination folder
# CKQ_H.parquet file already in the destination folder
# HSQ_H.parquet file already in the destination folder
# DEQ_H.parquet file already in the destination folder
# DIQ_H.parquet file already in the destination folder
# DBQ_H.parquet file already in the destination folder
# DLQ_H.parquet file already in the destination folder
# DUQ_H.parquet file already in the destination folder
# ECQ_H.parquet file already in the destination folder
# FSQ_H.parquet file already in the destination folder
# HIQ_H.parquet file already in the destination folder
# HEQ_H.parquet file already in the destination folder
# HUQ_H.parquet file already in the destination folder
# HOQ_H.parquet file already in the destination folder
# IMQ_H.parquet file already in the destination folder
# INQ_H.parquet file already in the destination folder
# KIQ_U_H.parquet file already in the destination folder
# MCQ_H.parquet file already in the destination folder
# DPQ_H.parquet file already in the destination folder
# OCQ_H.parquet file already in the destination folder
# OHQ_H.parquet file already in the destination folder
# OSQ_H.parquet file already in the destination folder
# PUQMEC_H.parquet file already in the destination folder
# PAQ_H.parquet file already in the destination folder
# PFQ_H.parquet file already in the destination folder
# RXQ_RX_H.parquet file already in the destination folder
# RXQASA_H.parquet file already in the destination folder
# RHQ_H.parquet file already in the destination folder
# SXQ_H.parquet file already in the destination folder
# SLQ_H.parquet file already in the destination folder
# SMQ_H.parquet file already in the destination folder
# SMQFAM_H.parquet file already in the destination folder
# SMQRTU_H.parquet file already in the destination folder
# SMQSHS_H.parquet file already in the destination folder
# CSQ_H.parquet file already in the destination folder
# VTQ_H.parquet file already in the destination folder
# WHQ_H.parquet file already in the destination folder
# WHQMEC_H.parquet file already in the destination folder
# __________________________

# %% [markdown]
# # 2. Download documentation for the variables.

# %%
def create_document_variables():

    df_docs = pd.DataFrame()
    data_type = ["Demographics", "Dietary", "Examination", "Questionnaire", "Laboratory"]
    for type in data_type:
        try:
            url = f"https://wwwn.cdc.gov/nchs/nhanes/search/variablelist.aspx?Component={type}&Cycle="
            df = pd.read_html(url)[0]
            df_docs = pd.concat([df_docs, df], ignore_index=True)
            print(f"Successfully scraped: {type} variable documentation")
        except Exception as e:
            print(f"Error scraping {type}: {str(e)}")

    df_docs['Year'] = df_docs['Begin Year'].astype(str) + "-" + df_docs['EndYear'].astype(str)
    
    return df_docs


#docs = create_document_variables()
#docs.to_csv(DATA_PATH + "documentation_variables.csv",index=False)
docs = pd.read_csv(DATA_PATH + "documentation_variables.csv")
docs
# Out:
#       Variable Name                               Variable Description  \
# 0           AIALANG     Language of the MEC ACASI Interview Instrument
# 1           DMDBORN            In what country {were you/was SP} born?
# 2          DMDCITZN  {Are you/Is SP} a citizen of the United States...
# 3          DMDEDUC2  (SP Interview Version) What is the highest gra...
# 4          DMDEDUC3  (SP Interview Version) What is the highest gra...
# ...             ...                                                ...
# 60957       LBXPFHS      Perfluorohexane sulfonic acid (PFHxS) (ng/mL)
# 60958       LBXPFNA              Perfluorononanoic acid (PFNA) (ng/mL)
# 60959       LBXPFUA            Perfluoroundecanoic acid (PFUA) (ng/mL)
# 60960          SEQN                        Respondent sequence number.
# 60961      WTSBAPRP                  Subsample BA Weights Pre-Pandemic
#
#       Data File Name                          Data File Description  \
# 0             DEMO_D         Demographic Variables & Sample Weights
# 1             DEMO_D         Demographic Variables & Sample Weights
# 2             DEMO_D         Demographic Variables & Sample Weights
# 3             DEMO_D         Demographic Variables & Sample Weights
# 4             DEMO_D         Demographic Variables & Sample Weights
# ...              ...                                            ...
# 60957         P_PFAS  Perfluoroalkyl and Polyfluoroalkyl Substances
# 60958         P_PFAS  Perfluoroalkyl and Polyfluoroalkyl Substances
# 60959         P_PFAS  Perfluoroalkyl and Polyfluoroalkyl Substances
# 60960         P_PFAS  Perfluoroalkyl and Polyfluoroalkyl Substances
# 60961         P_PFAS  Perfluoroalkyl and Polyfluoroalkyl Substances
#
#        Begin Year  EndYear     Component Use Constraints       Year
# 0            2005     2006  Demographics             NaN  2005-2006
# 1            2005     2006  Demographics             NaN  2005-2006
# 2            2005     2006  Demographics             NaN  2005-2006
# 3            2005     2006  Demographics             NaN  2005-2006
# 4            2005     2006  Demographics             NaN  2005-2006
# ...           ...      ...           ...             ...        ...
# 60957        2017     2020    Laboratory             NaN  2017-2020
# 60958        2017     2020    Laboratory             NaN  2017-2020
# 60959        2017     2020    Laboratory             NaN  2017-2020
# 60960        2017     2020    Laboratory             NaN  2017-2020
# 60961        2017     2020    Laboratory             NaN  2017-2020
#
# [60962 rows x 9 columns]

# %%
def glance_var_docs(var):
    df = docs[docs["Variable Name"] == var].sort_values("Year")
    df = df[df["Use Constraints"] != "RDC Only"]
    return df

glance_var_docs("RIDRETH1")
# Out:
#       Variable Name                               Variable Description  \
# 195        RIDRETH1  Recode of reported race and ethnicity informat...
# 156        RIDRETH1  Recode of reported race and ethnicity informat...
# 118        RIDRETH1  Recode of reported race and ethnicity informat...
# 32         RIDRETH1  Recode of reported race and ethnicity informat...
# 75         RIDRETH1  Recode of reported race and ethnicity informat...
# 55991      RIDRETH1  Recode of reported race and Hispanic origin in...
# 55753      RIDRETH1                                 Ethnicity - Recode
# 56111      RIDRETH1  Recode of reported race and Hispanic origin in...
# 343        RIDRETH1  Recode of reported race and ethnicity informat...
# 56033      RIDRETH1  Recode of reported race and Hispanic origin in...
# 858        RIDRETH1  Recode of reported race and Hispanic origin in...
# 1085       RIDRETH1  Recode of reported race and Hispanic origin in...
# 1556       RIDRETH1  Recode of reported race and Hispanic origin in...
# 1693       RIDRETH1  Recode of reported race and Hispanic origin in...
# 1722       RIDRETH1  Recode of reported race and Hispanic origin in...
#
#       Data File Name                              Data File Description  \
# 195             DEMO             Demographic Variables & Sample Weights
# 156           DEMO_B             Demographic Variables & Sample Weights
# 118           DEMO_C             Demographic Variables & Sample Weights
# 32            DEMO_D             Demographic Variables & Sample Weights
# 75            DEMO_E             Demographic Variables & Sample Weights
# 55991       PSTPOL_F  Pesticides - Organochlorine Pesticides - Poole...
# 55753       DOXPOL_F  Polychlorinated dibenzo-p-dioxins (PCDDs), Dib...
# 56111       PCBPOL_F  Non-dioxin-like Polychlorinated Biphenyls & Mo...
# 343           DEMO_F             Demographic Variables & Sample Weights
# 56033       BFRPOL_F  Brominated Flame Retardants (BFRs) - Pooled Sa...
# 858           DEMO_G             Demographic Variables & Sample Weights
# 1085          DEMO_H           Demographic Variables and Sample Weights
# 1556          DEMO_I           Demographic Variables and Sample Weights
# 1693          DEMO_J           Demographic Variables and Sample Weights
# 1722          P_DEMO           Demographic Variables and Sample Weights
#
#        Begin Year  EndYear     Component Use Constraints       Year
# 195          1999     2000  Demographics             NaN  1999-2000
# 156          2001     2002  Demographics             NaN  2001-2002
# 118          2003     2004  Demographics             NaN  2003-2004
# 32           2005     2006  Demographics             NaN  2005-2006
# 75           2007     2008  Demographics             NaN  2007-2008
# 55991        2009     2010    Laboratory             NaN  2009-2010
# 55753        2009     2010    Laboratory             NaN  2009-2010
# 56111        2009     2010    Laboratory             NaN  2009-2010
# 343          2009     2010  Demographics             NaN  2009-2010
# 56033        2009     2010    Laboratory             NaN  2009-2010
# 858          2011     2012  Demographics             NaN  2011-2012
# 1085         2013     2014  Demographics             NaN  2013-2014
# 1556         2015     2016  Demographics             NaN  2015-2016
# 1693         2017     2018  Demographics             NaN  2017-2018
# 1722         2017     2020  Demographics             NaN  2017-2020

# %% [markdown]
# # 3. Compile the variables needed based on paper.
#
# There are more than 3000 variables/columns in NHANES, we'll compile/stack only the ones we need to replicate the papers

# %%
def compile_data(variable_list, DATA_PATH=DATA_PATH, save_file_as=False):
    """
    for var in variable_list that you want: 
        - Look in the docs what parquet files contain that variable
        - Make a list called parquet_files that contains the path of the files.
        for file in parquet_files:
            - Read that file specific column variable + SEQN
            - Concat to the "master" dataframe 
            - Save the file if choosen 

    """
    docs_df = pd.read_csv(DATA_PATH + "documentation_variables.csv")
    docs_df = docs_df[docs_df["Use Constraints"] != "RDC Only"]

    # Initial dataset just with all the individual indexes and its year
    master_df = pd.DataFrame()

    file_path = sorted(glob(DATA_PATH + "**" + "/*DEMO*.parquet", recursive=True))
    for file in file_path:
        df = pd.read_parquet(file, columns=["SEQN"])
        df["YEAR"] = file[55:64]
        master_df = pd.concat([master_df, df], ignore_index=True)
    master_df.sort_values(by=["SEQN", "YEAR"], inplace=True)


    for var in variable_list:
        print(f"Searching for variable {var} ...")
        var = var.upper()
        parquet_files = sorted(docs_df[docs_df["Variable Name"] == var]['Data File Name'].unique())

        variable_concat_df = pd.DataFrame()
        for file in parquet_files:
            pattern = os.path.join(DATA_PATH, "**", f"{file}.parquet")
            file_path = glob(pattern, recursive=True)
            file_path = ''.join(file_path)
            if file_path:
                df = pd.read_parquet(file_path, columns=["SEQN", var])
                variable_concat_df = pd.concat([variable_concat_df, df], ignore_index=True)
                print(f"--> Successfully added: {var} from {file_path}")

        master_df = master_df.merge(variable_concat_df, on = ["SEQN"], how="left")

    if save_file_as:
        master_df.to_parquet(DATA_PATH + f"{save_file_as}.parquet", index=False)
        print("File saved inthe following folder: ", DATA_PATH)
    
    
    return master_df

# %% [markdown]
# ## 3.1 Dinh et al. (2019)
#
# The following file was created manually searching for the varaible names in the NHANES online "variable search tool" and taking the variables from the paper's figures.

# %%
dinh_2019_vars = pd.read_excel(DATA_PATH + "dinh_2019_variables_doc.xlsx")
dinh_2019_vars
# Out:
#                    Variable Name NHANES Name         NHANES File  \
# 0                            Age    RIDAGEYR                DEMO
# 1            Alcohol consumption      ALQ130                 ALQ
# 2                 Alcohol intake    DRXTALCO              DRXTOT
# 3      Alcohol intake, First Day    DR1TALCO              DR1TOT
# 4     Alcohol intake, Second Day    DR2TALCO              DR2TOT
# ..                           ...         ...                 ...
# 57                  Triglyceride    LBDSTRSI  LAB18, L40, BIOPRO
# 58           Waist circumference    BMXWAIST                 BMX
# 59                        Weight       BMXWT                 BMX
# 60        White blood cell count    LBXWBCSI     LAB25, L25, CBC
# 61  Alanine aminotransferase ALT    LBXSASSI  LAB18, L40, BIOPRO
#
#    NHANES Type of data                                Variable Definition
# 0         Demographics  Best age in years of the sample person at time...
# 1        Questionnaire  In the past 12 months, on those days that {you...
# 2              Dietary              Alcohol (gm) - Total Nutrient Intakes
# 3              Dietary  Alcohol (gm) - Total Nutrient Intakes, First Day
# 4              Dietary  Alcohol (gm) - Total Nutrient Intakes, Second ...
# ..                 ...                                                ...
# 57          Laboratory                             Triglycerides (mmol/L)
# 58         Examination                           Waist Circumference (cm)
# 59         Examination                                        Weight (kg)
# 60          Laboratory             White blood cell count (1000 cells/uL)
# 61          Laboratory               Aspartate aminotransferase AST (U/L)
#
# [62 rows x 5 columns]

# %%
dinh_variables = dinh_2019_vars["NHANES Name"].unique()

df = compile_data(dinh_variables, save_file_as="dinh_raw_data")
# Out:
# Searching for variable RIDAGEYR ...
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Demographics/DEMO.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Demographics/DEMO_B.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Demographics/DEMO_C.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Demographics/DEMO_D.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Demographics/DEMO_E.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Demographics/DEMO_F.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Demographics/DEMO_G.parquet
# --> Successfully added: RIDAGEYR from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Demographics/DEMO_H.parquet
# Searching for variable ALQ130 ...
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Questionnaire/ALQ.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/ALQ_B.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/ALQ_C.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/ALQ_D.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/ALQ_E.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/ALQ_F.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Questionnaire/ALQ_G.parquet
# --> Successfully added: ALQ130 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Questionnaire/ALQ_H.parquet
# Searching for variable DRXTALCO ...
# --> Successfully added: DRXTALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable DR1TALCO ...
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TALCO ...
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TALCO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable BMXARMC ...
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXARMC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable BMXARML ...
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXARML from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable LBXSOSSI ...
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/BIOPRO_D.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/BIOPRO_E.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/BIOPRO_F.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/BIOPRO_G.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/BIOPRO_H.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_B.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L40_C.parquet
# --> Successfully added: LBXSOSSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB18.parquet
# Searching for variable MCQ250A ...
# --> Successfully added: MCQ250A from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Questionnaire/MCQ.parquet
# --> Successfully added: MCQ250A from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/MCQ_B.parquet
# --> Successfully added: MCQ250A from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/MCQ_C.parquet
# Searching for variable LBDSBUSI ...
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/BIOPRO_D.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/BIOPRO_E.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/BIOPRO_F.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/BIOPRO_G.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/BIOPRO_H.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_B.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L40_C.parquet
# --> Successfully added: LBDSBUSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB18.parquet
# Searching for variable BMXBMI ...
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXBMI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable DRXTCAFF ...
# --> Successfully added: DRXTCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable DR1TCAFF ...
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TCAFF ...
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TCAFF from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable DR1TCALC ...
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TCALC ...
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable DRXTCALC ...
# --> Successfully added: DRXTCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTCALC from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable DR1TCARB ...
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TCARB ...
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable DRXTCARB ...
# --> Successfully added: DRXTCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTCARB from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable LB2SCLSI ...
# --> Successfully added: LB2SCLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_2_B.parquet
# Searching for variable MCQ300c ...
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/MCQ_D.parquet
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/MCQ_E.parquet
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/MCQ_F.parquet
# Searching for variable MCQ300C ...
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/MCQ_D.parquet
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/MCQ_E.parquet
# --> Successfully added: MCQ300C from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/MCQ_F.parquet
# Searching for variable BPXDI1 ...
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXDI1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXDI4 ...
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXDI4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXDI2 ...
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXDI2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXDI3 ...
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXDI3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable RIDRETH1 ...
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Demographics/DEMO.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Demographics/DEMO_B.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Demographics/DEMO_C.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Demographics/DEMO_D.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Demographics/DEMO_E.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Demographics/DEMO_F.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Demographics/DEMO_G.parquet
# --> Successfully added: RIDRETH1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Demographics/DEMO_H.parquet
# Searching for variable DR1TFIBE ...
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TFIBE ...
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable DRXTFIBE ...
# --> Successfully added: DRXTFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTFIBE from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable LBXSGTSI ...
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/BIOPRO_D.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/BIOPRO_E.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/BIOPRO_F.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/BIOPRO_G.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/BIOPRO_H.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_B.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L40_C.parquet
# --> Successfully added: LBXSGTSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB18.parquet
# Searching for variable HSD010 ...
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/HSQ_B.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/HSQ_C.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/HSQ_D.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/HSQ_E.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/HSQ_F.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Questionnaire/HSQ_G.parquet
# --> Successfully added: HSD010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Questionnaire/HSQ_H.parquet
# Searching for variable HUQ010 ...
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Questionnaire/HUQ.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/HUQ_B.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/HUQ_C.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/HUQ_D.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/HUQ_E.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/HUQ_F.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Questionnaire/HUQ_G.parquet
# --> Successfully added: HUQ010 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Questionnaire/HUQ_H.parquet
# Searching for variable LBDHDLSI ...
# --> Successfully added: LBDHDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/Lab13.parquet
# --> Successfully added: LBDHDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/l13_b.parquet
# Searching for variable LBDHDDSI ...
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/HDL_D.parquet
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/HDL_E.parquet
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/HDL_F.parquet
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/HDL_G.parquet
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/HDL_H.parquet
# --> Successfully added: LBDHDDSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/l13_c.parquet
# Searching for variable BMXHT ...
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXHT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable BPQ080 ...
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Questionnaire/BPQ.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/BPQ_B.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/BPQ_C.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/BPQ_D.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/BPQ_E.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/BPQ_F.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Questionnaire/BPQ_G.parquet
# --> Successfully added: BPQ080 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Questionnaire/BPQ_H.parquet
# Searching for variable INDHHIN2 ...
# --> Successfully added: INDHHIN2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Demographics/DEMO_E.parquet
# --> Successfully added: INDHHIN2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Demographics/DEMO_F.parquet
# --> Successfully added: INDHHIN2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Demographics/DEMO_G.parquet
# --> Successfully added: INDHHIN2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Demographics/DEMO_H.parquet
# Searching for variable DRXTKCAL ...
# --> Successfully added: DRXTKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRXTKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable DR1TKCAL ...
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TKCAL ...
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TKCAL from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable LBDLDLSI ...
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L13AM_B.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L13AM_C.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB13AM.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/TRIGLY_D.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/TRIGLY_E.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/TRIGLY_F.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/TRIGLY_G.parquet
# --> Successfully added: LBDLDLSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/TRIGLY_H.parquet
# Searching for variable BMXLEG ...
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXLEG from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable LBDLYMNO ...
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/CBC_D.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/CBC_E.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/CBC_F.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/CBC_G.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/CBC_H.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L25_B.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L25_C.parquet
# --> Successfully added: LBDLYMNO from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB25.parquet
# Searching for variable LBXMCVSI ...
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/CBC_D.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/CBC_E.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/CBC_F.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/CBC_G.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/CBC_H.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L25_B.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L25_C.parquet
# --> Successfully added: LBXMCVSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB25.parquet
# Searching for variable BPXPLS ...
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXPLS from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable WHD140 ...
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Questionnaire/WHQ.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Questionnaire/WHQ_B.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Questionnaire/WHQ_C.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Questionnaire/WHQ_D.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Questionnaire/WHQ_E.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Questionnaire/WHQ_F.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Questionnaire/WHQ_G.parquet
# --> Successfully added: WHD140 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Questionnaire/WHQ_H.parquet
# Searching for variable DR1TSODI ...
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR1TOT_C.parquet
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR1TOT_D.parquet
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR1TOT_E.parquet
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR1TOT_F.parquet
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR1TOT_G.parquet
# --> Successfully added: DR1TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR1TOT_H.parquet
# Searching for variable DR2TSODI ...
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Dietary/DR2TOT_C.parquet
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Dietary/DR2TOT_D.parquet
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Dietary/DR2TOT_E.parquet
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Dietary/DR2TOT_F.parquet
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Dietary/DR2TOT_G.parquet
# --> Successfully added: DR2TSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Dietary/DR2TOT_H.parquet
# Searching for variable DRDTSODI ...
# --> Successfully added: DRDTSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Dietary/DRXTOT.parquet
# --> Successfully added: DRDTSODI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Dietary/DRXTOT_B.parquet
# Searching for variable BPXSY1 ...
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXSY1 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXSY4 ...
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXSY4 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXSY2 ...
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXSY2 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable BPXSY3 ...
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BPX.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BPX_B.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BPX_C.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BPX_D.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BPX_E.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BPX_F.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BPX_G.parquet
# --> Successfully added: BPXSY3 from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BPX_H.parquet
# Searching for variable LBDTCSI ...
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/Lab13.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/TCHOL_D.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/TCHOL_E.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/TCHOL_F.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/TCHOL_G.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/TCHOL_H.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/l13_b.parquet
# --> Successfully added: LBDTCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/l13_c.parquet
# Searching for variable LBDSTRSI ...
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/BIOPRO_D.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/BIOPRO_E.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/BIOPRO_F.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/BIOPRO_G.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/BIOPRO_H.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_B.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L40_C.parquet
# --> Successfully added: LBDSTRSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB18.parquet
# Searching for variable BMXWAIST ...
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXWAIST from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable BMXWT ...
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Examination/BMX.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Examination/BMX_B.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Examination/BMX_C.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Examination/BMX_D.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Examination/BMX_E.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Examination/BMX_F.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Examination/BMX_G.parquet
# --> Successfully added: BMXWT from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Examination/BMX_H.parquet
# Searching for variable LBXWBCSI ...
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/CBC_D.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/CBC_E.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/CBC_F.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/CBC_G.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/CBC_H.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L25_B.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L25_C.parquet
# --> Successfully added: LBXWBCSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB25.parquet
# Searching for variable LBXSASSI ...
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2005-2006/Laboratory/BIOPRO_D.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2007-2008/Laboratory/BIOPRO_E.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2009-2010/Laboratory/BIOPRO_F.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2011-2012/Laboratory/BIOPRO_G.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2013-2014/Laboratory/BIOPRO_H.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2001-2002/Laboratory/L40_B.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/2003-2004/Laboratory/L40_C.parquet
# --> Successfully added: LBXSASSI from /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/1999-2000/Laboratory/LAB18.parquet
# File saved inthe following folder:  /Users/pipegalera/dev/ml_diabetes/data/NHANES/raw_data/

# %%
df
# Out:
#           SEQN       YEAR  RIDAGEYR  ALQ130  DRXTALCO  DR1TALCO  DR2TALCO  \
# 0          1.0  1999-2000       2.0     NaN      0.00       NaN       NaN
# 1          2.0  1999-2000      77.0     1.0      0.00       NaN       NaN
# 2          3.0  1999-2000      10.0     NaN      0.00       NaN       NaN
# 3          4.0  1999-2000       1.0     NaN      0.00       NaN       NaN
# 4          5.0  1999-2000      49.0     3.0     34.56       NaN       NaN
# ...        ...        ...       ...     ...       ...       ...       ...
# 82086  83727.0  2013-2014      26.0     3.0       NaN      14.0      19.9
# 82087  83728.0  2013-2014       2.0     NaN       NaN       0.0       0.0
# 82088  83729.0  2013-2014      42.0     NaN       NaN       0.0       0.0
# 82089  83730.0  2013-2014       7.0     NaN       NaN       NaN       NaN
# 82090  83731.0  2013-2014      11.0     NaN       NaN       0.0       0.0
#
#        BMXARMC  BMXARML  LBXSOSSI  ...  BPXSY1  BPXSY4  BPXSY2  BPXSY3  \
# 0         15.2     18.6       NaN  ...     NaN     NaN     NaN     NaN
# 1         29.8     38.2     288.0  ...   106.0     NaN    98.0    98.0
# 2         19.7     25.5       NaN  ...   110.0     NaN   104.0   112.0
# 3         16.4     20.4       NaN  ...     NaN     NaN     NaN     NaN
# 4         35.8     39.7     276.0  ...   122.0     NaN   122.0   122.0
# ...        ...      ...       ...  ...     ...     ...     ...     ...
# 82086     29.9     35.2     285.0  ...   110.0     NaN   116.0   112.0
# 82087     14.7     16.5       NaN  ...     NaN     NaN     NaN     NaN
# 82088     37.0     37.6     277.0  ...   136.0     NaN   130.0   138.0
# 82089     19.0     26.0       NaN  ...     NaN     NaN     NaN     NaN
# 82090     25.0     31.7       NaN  ...    94.0     NaN    94.0    90.0
#
#        LBDTCSI  LBDSTRSI  BMXWAIST  BMXWT  LBXWBCSI  LBXSASSI
# 0          NaN       NaN      45.7   12.5       NaN       NaN
# 1         5.56     1.298      98.0   75.4       7.6      19.0
# 2         3.34       NaN      64.7   32.9       7.5       NaN
# 3          NaN       NaN       NaN   13.3       8.8       NaN
# 4         7.21     3.850      99.9   92.5       5.9      22.0
# ...        ...       ...       ...    ...       ...       ...
# 82086     4.91     0.858      87.1   71.8       5.1      27.0
# 82087      NaN       NaN      47.2   11.3       6.6       NaN
# 82088     3.93     1.197     102.7   89.6       6.4      26.0
# 82089     4.32       NaN      53.0   22.8       9.9       NaN
# 82090      NaN       NaN      73.5   42.3       NaN       NaN
#
# [82091 rows x 63 columns]

# %% [markdown]
# # 4. Prep the data

# %% [markdown]
# There are some fixes before the data is ready for analysis from variables that are the same but called diffrenet in different NHANES years:
#
# 1. Intake variables went from 1 day in 1999 to 2001 to 2 days from 2003 on, therefore the variable has to be homogenized. I take the average of both days. This happends with:
#
# - Alcohol intake (`DRXTALCO`, `DR1TALCO`, `DR2TALCO`)
# - Caffeine intake (`DRXTCAFF`, `DR1TCAFF`, `DR2TCAFF`)
# - Calcium intake (`DRXTCALC`, `DR1TCALC`, `DR2TCALC`)
# - Carbohydrate intake (`DRXTCARB`, `DR1TCARB`, `DR2TCARB`)
# - Fiber intake (`DRXTFIBE`, `DR1TFIBE`, `DR2TFIBE`)
# - Kcal intake (`DRXTKCAL`, `DR1TKCAL`, `DR2TKCAL`)
# - Sodium intake (`DRDTSODI`, `DR1TSODI`, `DR2TSODI`)

# %%
glance_var_docs("DRDTSODI")
# Out:
#      Variable Name                               Variable Description  \
# 1889      DRDTSODI  Sodium (mg) (adjusted for salt use in food pre...
# 2058      DRDTSODI  Sodium (mg) (adjusted for salt use in food pre...
#
#      Data File Name                       Data File Description  Begin Year  \
# 1889         DRXTOT  Dietary Interview - Total Nutrient Intakes        1999
# 2058       DRXTOT_B  Dietary Interview - Total Nutrient Intakes        2001
#
#       EndYear Component Use Constraints       Year
# 1889     2000   Dietary             NaN  1999-2000
# 2058     2002   Dietary             NaN  2001-2002

# %%
glance_var_docs("DR1TSODI")
# Out:
#      Variable Name                               Variable Description  \
# 2738      DR1TSODI  Sodium (mg) (adjusted for salt use in food pre...
# 5542      DR1TSODI  Sodium (mg) (adjusted for salt use in food pre...
# 4416      DR1TSODI  Sodium (mg) (adjusted for salt use in food pre...
# 3684      DR1TSODI                                        Sodium (mg)
# 4713      DR1TSODI                                        Sodium (mg)
# 5879      DR1TSODI                                        Sodium (mg)
# 6625      DR1TSODI                                        Sodium (mg)
# 7367      DR1TSODI                                        Sodium (mg)
# 8477      DR1TSODI                                        Sodium (mg)
#
#      Data File Name                              Data File Description  \
# 2738       DR1TOT_C  Dietary Interview - Total Nutrient Intakes, Fi...
# 5542       DR1TOT_D  Dietary Interview - Total Nutrient Intakes, Fi...
# 4416       DR1TOT_E  Dietary Interview - Total Nutrient Intakes, Fi...
# 3684       DR1TOT_F  Dietary Interview - Total Nutrient Intakes, Fi...
# 4713       DR1TOT_G  Dietary Interview - Total Nutrient Intakes, Fi...
# 5879       DR1TOT_H  Dietary Interview - Total Nutrient Intakes, Fi...
# 6625       DR1TOT_I  Dietary Interview - Total Nutrient Intakes, Fi...
# 7367       DR1TOT_J  Dietary Interview - Total Nutrient Intakes, Fi...
# 8477       P_DR1TOT  Dietary Interview - Total Nutrient Intakes, Fi...
#
#       Begin Year  EndYear Component Use Constraints       Year
# 2738        2003     2004   Dietary             NaN  2003-2004
# 5542        2005     2006   Dietary             NaN  2005-2006
# 4416        2007     2008   Dietary             NaN  2007-2008
# 3684        2009     2010   Dietary             NaN  2009-2010
# 4713        2011     2012   Dietary             NaN  2011-2012
# 5879        2013     2014   Dietary             NaN  2013-2014
# 6625        2015     2016   Dietary             NaN  2015-2016
# 7367        2017     2018   Dietary             NaN  2017-2018
# 8477        2017     2020   Dietary             NaN  2017-2020

# %% [markdown]
# 2. Changes in same quesion format:
#     - `MCQ250A`, `MCQ300A`, and `MCQ300c` are the same question with a change in the formulatting over the years.
#     - `LBDHDDSI` and `LBDHDLSI` are the same variable for HDL-choresterol

# %%
glance_var_docs("MCQ250A")
# Out:
#       Variable Name                               Variable Description  \
# 30290       MCQ250A  Including living and deceased, were any of {SP...
# 33832       MCQ250A  Including living and deceased, were any of {SP...
# 32697       MCQ250A  Including living and deceased, were any of {SP...
#
#       Data File Name Data File Description  Begin Year  EndYear  \
# 30290            MCQ    Medical Conditions        1999     2000
# 33832          MCQ_B    Medical Conditions        2001     2002
# 32697          MCQ_C    Medical Conditions        2003     2004
#
#            Component Use Constraints       Year
# 30290  Questionnaire             NaN  1999-2000
# 33832  Questionnaire             NaN  2001-2002
# 32697  Questionnaire             NaN  2003-2004

# %%
glance_var_docs("MCQ300C")
# Out:
#       Variable Name                               Variable Description  \
# 31603       MCQ300C  Including living and deceased, were any of {SP...
# 28503       MCQ300C  Including living and deceased, were any of {SP...
# 35450       MCQ300C  Including living and deceased, were any of {SP...
#
#       Data File Name Data File Description  Begin Year  EndYear  \
# 31603          MCQ_D    Medical Conditions        2005     2006
# 28503          MCQ_E    Medical Conditions        2007     2008
# 35450          MCQ_F    Medical Conditions        2009     2010
#
#            Component Use Constraints       Year
# 31603  Questionnaire             NaN  2005-2006
# 28503  Questionnaire             NaN  2007-2008
# 35450  Questionnaire             NaN  2009-2010

# %%
glance_var_docs("MCQ300c")
# Out:
#       Variable Name                               Variable Description  \
# 40662       MCQ300c  Including living and deceased, were any of {SP...
# 41620       MCQ300c  Including living and deceased, were any of {SP...
# 43069       MCQ300c  Including living and deceased, were any of {SP...
# 44380       MCQ300c  Including living and deceased, were any of {SP...
# 45817       MCQ300c  Including living and deceased, were any of {SP...
#
#       Data File Name Data File Description  Begin Year  EndYear  \
# 40662          MCQ_G    Medical Conditions        2011     2012
# 41620          MCQ_H    Medical Conditions        2013     2014
# 43069          MCQ_I    Medical Conditions        2015     2016
# 44380          MCQ_J    Medical Conditions        2017     2018
# 45817          P_MCQ    Medical Conditions        2017     2020
#
#            Component Use Constraints       Year
# 40662  Questionnaire             NaN  2011-2012
# 41620  Questionnaire             NaN  2013-2014
# 43069  Questionnaire             NaN  2015-2016
# 44380  Questionnaire             NaN  2017-2018
# 45817  Questionnaire             NaN  2017-2020

# %%
glance_var_docs("LBDHDLSI")
# Out:
#       Variable Name      Variable Description Data File Name  \
# 47584      LBDHDLSI  HDL-cholesterol (mmol/L)          Lab13
# 47967      LBDHDLSI  HDL-cholesterol (mmol/L)          l13_b
#
#            Data File Description  Begin Year  EndYear   Component  \
# 47584  Cholesterol - Total & HDL        1999     2000  Laboratory
# 47967  Cholesterol - Total & HDL        2001     2002  Laboratory
#
#       Use Constraints       Year
# 47584             NaN  1999-2000
# 47967             NaN  2001-2002

# %%
glance_var_docs("LBDHDDSI")
# Out:
#       Variable Name             Variable Description Data File Name  \
# 47971      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          l13_c
# 47980      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_D
# 47263      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_E
# 50841      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_F
# 52819      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_G
# 53631      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_H
# 56277      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_I
# 58730      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          HDL_J
# 59824      LBDHDDSI  Direct HDL-Cholesterol (mmol/L)          P_HDL
#
#                                 Data File Description  Begin Year  EndYear  \
# 47971                       Cholesterol - Total & HDL        2003     2004
# 47980                               Cholesterol - HDL        2005     2006
# 47263                               Cholesterol - HDL        2007     2008
# 50841                               Cholesterol - HDL        2009     2010
# 52819                               Cholesterol - HDL        2011     2012
# 53631                               Cholesterol - HDL        2013     2014
# 56277    Cholesterol - High-Density Lipoprotein (HDL)        2015     2016
# 58730  Cholesterol - High - Density Lipoprotein (HDL)        2017     2018
# 59824  Cholesterol - High - Density Lipoprotein (HDL)        2017     2020
#
#         Component Use Constraints       Year
# 47971  Laboratory             NaN  2003-2004
# 47980  Laboratory             NaN  2005-2006
# 47263  Laboratory             NaN  2007-2008
# 50841  Laboratory             NaN  2009-2010
# 52819  Laboratory             NaN  2011-2012
# 53631  Laboratory             NaN  2013-2014
# 56277  Laboratory             NaN  2015-2016
# 58730  Laboratory             NaN  2017-2018
# 59824  Laboratory             NaN  2017-2020
